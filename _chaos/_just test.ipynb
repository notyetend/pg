# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

x = np.linspace(-900, 900, 100)
y = 1 / (1 + 10**(-x/400))
plt.plot(x, y, label='prior');

# %%
import numpy as np
x = np.random.randn(2, 10)
y = np.zeros(10)

# %%
x.shape
# Out:
# (2, 10)

# %%
for i in range(len(y)):
    y[i] = 1 if x[:,i] > 0.5 else 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d975cc02da14> in <module>()
#       1 for i in range(len(y)):
# ----> 2     y[i] = 1 if x[:,i] > 0.5 else 0
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
y
# Out:
# array([ 0.,  0.,  1.,  0.,  1.,  1.,  0.,  0.,  0.,  0.])

# %%
64*64*3
# Out:
# 12288

# %% [markdown]
# ![gargouille.jpg](attachment:gargouille.jpg)

# %% [markdown]
# ![la_defense.jpg](attachment:la_defense.jpg)

# %%
import numpy as np

# %%
x = np.random.randn(3,2)

# %%
x
# Out:
# array([[ 1.15119966, -0.46276724],
#        [ 1.30589819, -0.35592968],
#        [-0.30311643,  1.54504531]])

# %%
x.shape
# Out:
# (3, 2)

# %%
y
# Out:
# array([[1, 2]])

# %%
y = np.array([1,2]).reshape(1, 2); y.shape
# Out:
# (1, 2)

# %%
x + y
# Out:
# array([[ 2.15119966,  1.53723276],
#        [ 2.30589819,  1.64407032],
#        [ 0.69688357,  3.54504531]])

# %%
z = np.random.randn(3); z
# Out:
# array([ 1.30172577,  0.92970584,  0.76601789])

# %%
z.shape
# Out:
# (3,)

# %% [markdown]
# ###### Original

# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 300


# 카트폴 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False
        self.load_model = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = self.build_model()
        self.target_model = self.build_model()

        # 타깃 모델 초기화
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_dqn_trained.h5")

    # 상태가 입력, 큐함수가 출력인 인공신경망 생성
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(24, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.zeros((self.batch_size, self.state_size))
        next_states = np.zeros((self.batch_size, self.state_size))
        actions, rewards, dones = [], [], []

        for i in range(self.batch_size):
            states[i] = mini_batch[i][0]
            actions.append(mini_batch[i][1])
            rewards.append(mini_batch[i][2])
            next_states[i] = mini_batch[i][3]
            dones.append(mini_batch[i][4])

        # 현재 상태에 대한 모델의 큐함수
        # 다음 상태에 대한 타깃 모델의 큐함수
        target = self.model.predict(states)
        target_val = self.target_model.predict(next_states)

        # 벨만 최적 방정식을 이용한 업데이트 타깃
        for i in range(self.batch_size):
            if dones[i]:
                target[i][actions[i]] = rewards[i]
            else:
                target[i][actions[i]] = rewards[i] + self.discount_factor * (
                    np.amax(target_val[i]))

        self.model.fit(states, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)


if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            # 에피소드가 중간에 끝나면 -100 보상
            reward = reward if not done or score == 499 else -100

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            score += reward
            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()

                score = score if score == 500 else score + 100
                # 에피소드마다 학습 결과 출력
                scores.append(score)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.savefig("./save_graph/cartpole_dqn.png")
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)

                # 이전 10개 에피소드의 점수 평균이 490보다 크면 학습 중단
                if np.mean(scores[-min(10, len(scores)):]) > 490:
                    agent.model.save_weights("./save_model/cartpole_dqn.h5")
                    sys.exit()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 16.0   memory length: 17   epsilon: 1.0
# episode: 1   score: 14.0   memory length: 32   epsilon: 1.0
# episode: 2   score: 10.0   memory length: 43   epsilon: 1.0
# episode: 3   score: 16.0   memory length: 60   epsilon: 1.0
# episode: 4   score: 11.0   memory length: 72   epsilon: 1.0
# episode: 5   score: 16.0   memory length: 89   epsilon: 1.0
# episode: 6   score: 25.0   memory length: 115   epsilon: 1.0
# episode: 7   score: 21.0   memory length: 137   epsilon: 1.0
# episode: 8   score: 26.0   memory length: 164   epsilon: 1.0
# episode: 9   score: 26.0   memory length: 191   epsilon: 1.0
# episode: 10   score: 26.0   memory length: 218   epsilon: 1.0
# episode: 11   score: 26.0   memory length: 245   epsilon: 1.0
# episode: 12   score: 17.0   memory length: 263   epsilon: 1.0
# episode: 13   score: 17.0   memory length: 281   epsilon: 1.0
# episode: 14   score: 24.0   memory length: 306   epsilon: 1.0
# episode: 15   score: 15.0   memory length: 322   epsilon: 1.0
# episode: 16   score: 14.0   memory length: 337   epsilon: 1.0
# episode: 17   score: 24.0   memory length: 362   epsilon: 1.0
# episode: 18   score: 8.0   memory length: 371   epsilon: 1.0
# episode: 19   score: 23.0   memory length: 395   epsilon: 1.0
# episode: 20   score: 15.0   memory length: 411   epsilon: 1.0
# episode: 21   score: 21.0   memory length: 433   epsilon: 1.0
# episode: 22   score: 25.0   memory length: 459   epsilon: 1.0
# episode: 23   score: 22.0   memory length: 482   epsilon: 1.0
# episode: 24   score: 26.0   memory length: 509   epsilon: 1.0
# episode: 25   score: 11.0   memory length: 521   epsilon: 1.0
# episode: 26   score: 11.0   memory length: 533   epsilon: 1.0
# episode: 27   score: 44.0   memory length: 578   epsilon: 1.0
# episode: 28   score: 19.0   memory length: 598   epsilon: 1.0
# episode: 29   score: 26.0   memory length: 625   epsilon: 1.0
# episode: 30   score: 12.0   memory length: 638   epsilon: 1.0
# episode: 31   score: 16.0   memory length: 655   epsilon: 1.0
# episode: 32   score: 12.0   memory length: 668   epsilon: 1.0
# episode: 33   score: 14.0   memory length: 683   epsilon: 1.0
# episode: 34   score: 11.0   memory length: 695   epsilon: 1.0
# episode: 35   score: 13.0   memory length: 709   epsilon: 1.0
# episode: 36   score: 16.0   memory length: 726   epsilon: 1.0
# episode: 37   score: 49.0   memory length: 776   epsilon: 1.0
# episode: 38   score: 23.0   memory length: 800   epsilon: 1.0
# episode: 39   score: 8.0   memory length: 809   epsilon: 1.0
# episode: 40   score: 15.0   memory length: 825   epsilon: 1.0
# episode: 41   score: 20.0   memory length: 846   epsilon: 1.0
# episode: 42   score: 15.0   memory length: 862   epsilon: 1.0
# episode: 43   score: 18.0   memory length: 881   epsilon: 1.0
# episode: 44   score: 22.0   memory length: 904   epsilon: 1.0
# episode: 45   score: 18.0   memory length: 923   epsilon: 1.0
# episode: 46   score: 14.0   memory length: 938   epsilon: 1.0
# episode: 47   score: 21.0   memory length: 960   epsilon: 1.0
# episode: 48   score: 14.0   memory length: 975   epsilon: 1.0
# episode: 49   score: 14.0   memory length: 990   epsilon: 1.0
# episode: 50   score: 65.0   memory length: 1056   epsilon: 0.9445671308589195
# episode: 51   score: 18.0   memory length: 1075   epsilon: 0.9267809647166116
# episode: 52   score: 23.0   memory length: 1099   epsilon: 0.9047921471137096
# episode: 53   score: 14.0   memory length: 1114   epsilon: 0.8913148576343527
# episode: 54   score: 17.0   memory length: 1132   epsilon: 0.8754068367770318
# episode: 55   score: 35.0   memory length: 1168   epsilon: 0.8444374977929298
# episode: 56   score: 17.0   memory length: 1186   epsilon: 0.8293661352855802
# episode: 57   score: 28.0   memory length: 1215   epsilon: 0.8056482291095421
# episode: 58   score: 58.0   memory length: 1274   epsilon: 0.759467619567903
# episode: 59   score: 42.0   memory length: 1317   epsilon: 0.7274870315965022
# episode: 60   score: 7.0   memory length: 1325   epsilon: 0.7216874642922244
# episode: 61   score: 23.0   memory length: 1349   epsilon: 0.704564697832001
# episode: 62   score: 24.0   memory length: 1374   epsilon: 0.6871603381721801
# episode: 63   score: 42.0   memory length: 1417   epsilon: 0.6582245533155777
# episode: 64   score: 157.0   memory length: 1575   epsilon: 0.5619804635022894
# episode: 65   score: 111.0   memory length: 1687   epsilon: 0.5024072518560504
# episode: 66   score: 192.0   memory length: 1880   epsilon: 0.4141857253125019
# episode: 67   score: 109.0   memory length: 1990   epsilon: 0.37102129074024554
# episode: 68   score: 140.0   memory length: 2000   epsilon: 0.3222052939901265
# episode: 69   score: 68.0   memory length: 2000   epsilon: 0.3007124156643058
# episode: 70   score: 165.0   memory length: 2000   epsilon: 0.2546961644985321
# episode: 71   score: 156.0   memory length: 2000   epsilon: 0.21767274617993623
# episode: 72   score: 121.0   memory length: 2000   epsilon: 0.19266091563311397
# episode: 73   score: 188.0   memory length: 2000   epsilon: 0.15946702592761744
# episode: 74   score: 254.0   memory length: 2000   epsilon: 0.12355786412844308
# episode: 75   score: 307.0   memory length: 2000   epsilon: 0.0907905748536994
# episode: 76   score: 187.0   memory length: 2000   epsilon: 0.07522332955858199
# episode: 77   score: 369.0   memory length: 2000   epsilon: 0.05194971819092284
# episode: 78   score: 319.0   memory length: 2000   epsilon: 0.03771719857917758
# episode: 79   score: 333.0   memory length: 2000   epsilon: 0.027003029805995952
# episode: 80   score: 191.0   memory length: 2000   epsilon: 0.02228364520898687
# episode: 81   score: 500.0   memory length: 2000   epsilon: 0.013512333269486445
# episode: 82   score: 250.0   memory length: 2000   epsilon: 0.010511577409633223
# episode: 83   score: 283.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 84   score: 326.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 85   score: 288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 86   score: 267.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 87   score: 337.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 88   score: 277.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 89   score: 238.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 90   score: 316.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 91   score: 300.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 92   score: 323.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 93   score: 433.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 94   score: 301.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 95   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 96   score: 338.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 97   score: 295.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 98   score: 331.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 99   score: 421.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 100   score: 223.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 101   score: 306.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 102   score: 286.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 103   score: 439.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 104   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 105   score: 340.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 106   score: 345.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 107   score: 269.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 108   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 109   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 110   score: 449.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 111   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 112   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 113   score: 394.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 114   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 115   score: 308.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 116   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 117   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 118   score: 457.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 119   score: 478.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 120   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 121   score: 407.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 122   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 123   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 124   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 125   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 126   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 127   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 128   score: 482.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 129   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 130   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 131   score: 455.0   memory length: 2000   epsilon: 0.009998671593271896
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 100  # 300

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False
        self.load_model = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 100  # 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = self.build_model()
        self.target_model = self.build_model()

        # 타깃 모델 초기화
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_dqn_trained.h5")
        
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(24, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model
        
    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        
        return random.randrange(self.action_size)
        '''
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])
        '''

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
            
        mini_batch = random.sample(self.memory, self.batch_size)
        
        states = np.zeros((self.batch_size, self.state_size))
        next_states = np.zeros((self.batch_size, self.state_size))
        actions, rewards, dones = [], [], []
        
        for i in range(self.batch_size):
            states[i] = mini_batch[i][0]
            actions.append(mini_batch[i][1])
            rewards.append(mini_batch[i][2])
            next_states[i] = mini_batch[i][3]
            dones.append(mini_batch[i][4])
            
        target = self.model.predict(states)
        target_val = self.target_model.predict(next_states)
        
        print('>', type(target), target.shape, target[0])

# %%
if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        # while not done:
        for _ in range(100):
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            # 에피소드가 중간에 끝나면 -100 보상
            reward = reward if not done or score == 499 else -100

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            score += reward
            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()

                score = score if score == 500 else score + 100
                # 에피소드마다 학습 결과 출력
                scores.append(score)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.savefig("./save_graph/cartpole_dqn.png")
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)

                # 이전 10개 에피소드의 점수 평균이 490보다 크면 학습 중단
                if np.mean(scores[-min(10, len(scores)):]) > 490:
                    agent.model.save_weights("./save_model/cartpole_dqn.h5")
                    sys.exit()
                
                break
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_44 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_45 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_47 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_48 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 33.0   memory length: 34   epsilon: 1.0
# episode: 1   score: 31.0   memory length: 66   epsilon: 1.0
# > <class 'numpy.ndarray'> (64, 2) [-0.25398782 -0.06826548]
# > <class 'numpy.ndarray'> (64, 2) [-0.10509427 -0.11983375]
# episode: 2   score: 34.0   memory length: 101   epsilon: 0.998001
# > <class 'numpy.ndarray'> (64, 2) [-0.31213981  0.00692637]
# > <class 'numpy.ndarray'> (64, 2) [-0.75429225 -0.1047762 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.23392853 -0.02846856]
# > <class 'numpy.ndarray'> (64, 2) [-0.00809767 -0.0343395 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.13630171 -0.10888186]
# > <class 'numpy.ndarray'> (64, 2) [-0.92931378 -0.11235711]
# > <class 'numpy.ndarray'> (64, 2) [-0.49712074 -0.13938162]
# > <class 'numpy.ndarray'> (64, 2) [-0.1154043  -0.12850292]
# > <class 'numpy.ndarray'> (64, 2) [-0.13445738 -0.12612669]
# > <class 'numpy.ndarray'> (64, 2) [-0.1329014  -0.12572308]
# > <class 'numpy.ndarray'> (64, 2) [-0.33629984 -0.32157612]
# > <class 'numpy.ndarray'> (64, 2) [-0.2741172  -0.13817646]
# > <class 'numpy.ndarray'> (64, 2) [-0.42159498 -0.43341771]
# > <class 'numpy.ndarray'> (64, 2) [-0.30196226 -0.16512567]
# episode: 3   score: 13.0   memory length: 115   epsilon: 0.98411944181564
# > <class 'numpy.ndarray'> (64, 2) [-0.15924914 -0.12237028]
# > <class 'numpy.ndarray'> (64, 2) [-0.31213981  0.00692637]
# > <class 'numpy.ndarray'> (64, 2) [-0.05142007 -0.02122422]
# > <class 'numpy.ndarray'> (64, 2) [-0.34445709 -0.08343967]
# > <class 'numpy.ndarray'> (64, 2) [-0.04000062 -0.04576771]
# > <class 'numpy.ndarray'> (64, 2) [-0.12383145 -0.13647608]
# > <class 'numpy.ndarray'> (64, 2) [-0.06812648 -0.10851748]
# > <class 'numpy.ndarray'> (64, 2) [-0.33965334 -0.31683379]
# > <class 'numpy.ndarray'> (64, 2) [-0.76487815 -0.08918971]
# > <class 'numpy.ndarray'> (64, 2) [-0.13445738 -0.12612669]
# > <class 'numpy.ndarray'> (64, 2) [-0.39298671 -0.39332709]
# > <class 'numpy.ndarray'> (64, 2) [-0.41260269 -0.01493207]
# > <class 'numpy.ndarray'> (64, 2) [-0.31629345  0.00365281]
# > <class 'numpy.ndarray'> (64, 2) [-0.04984751 -0.01973659]
# > <class 'numpy.ndarray'> (64, 2) [-0.07243665 -0.01279089]
# > <class 'numpy.ndarray'> (64, 2) [-0.04984751 -0.01973659]
# > <class 'numpy.ndarray'> (64, 2) [-0.06608663 -0.11021072]
# > <class 'numpy.ndarray'> (64, 2) [-0.06812648 -0.10851748]
# > <class 'numpy.ndarray'> (64, 2) [-0.25728261 -0.00986446]
# > <class 'numpy.ndarray'> (64, 2) [-0.11822213 -0.11978769]
# > <class 'numpy.ndarray'> (64, 2) [-0.11822213 -0.11978769]
# > <class 'numpy.ndarray'> (64, 2) [-0.54551935 -0.52127278]
# > <class 'numpy.ndarray'> (64, 2) [-0.25182605 -0.23117758]
# > <class 'numpy.ndarray'> (64, 2) [-0.13478523 -0.14048247]
# > <class 'numpy.ndarray'> (64, 2) [-0.24394913 -0.08663494]
# > <class 'numpy.ndarray'> (64, 2) [-0.05021153 -0.01185473]
# > <class 'numpy.ndarray'> (64, 2) [-0.24394913 -0.08663494]
# > <class 'numpy.ndarray'> (64, 2) [-0.49203235 -0.00217526]
# > <class 'numpy.ndarray'> (64, 2) [-0.82556391 -0.80421269]
# > <class 'numpy.ndarray'> (64, 2) [-0.13630171 -0.10888186]
# > <class 'numpy.ndarray'> (64, 2) [-0.28980154 -0.00357166]
# > <class 'numpy.ndarray'> (64, 2) [-0.25728261 -0.00986446]
# > <class 'numpy.ndarray'> (64, 2) [-0.15924914 -0.12237028]
# episode: 4   score: 32.0   memory length: 148   epsilon: 0.9521577859830145
# > <class 'numpy.ndarray'> (64, 2) [-0.06877009 -0.03084124]
# > <class 'numpy.ndarray'> (64, 2) [-0.04675858 -0.03154506]
# > <class 'numpy.ndarray'> (64, 2) [-0.13445738 -0.12612669]
# > <class 'numpy.ndarray'> (64, 2) [-0.06877009 -0.03084124]
# > <class 'numpy.ndarray'> (64, 2) [-0.39587864 -0.13132669]
# > <class 'numpy.ndarray'> (64, 2) [-0.01007408 -0.23950867]
# > <class 'numpy.ndarray'> (64, 2) [-0.29344144 -0.05837439]
# > <class 'numpy.ndarray'> (64, 2) [-0.05197241 -0.05663413]
# > <class 'numpy.ndarray'> (64, 2) [-0.39298671 -0.39332709]
# > <class 'numpy.ndarray'> (64, 2) [-0.54551935 -0.52127278]
# > <class 'numpy.ndarray'> (64, 2) [-0.59443426 -0.0718556 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.11580379 -0.12518728]
# > <class 'numpy.ndarray'> (64, 2) [-0.16211346 -0.12658808]
# > <class 'numpy.ndarray'> (64, 2) [-0.07596254 -0.03009541]
# > <class 'numpy.ndarray'> (64, 2) [-0.87512898 -0.03757912]
# > <class 'numpy.ndarray'> (64, 2) [-0.11580379 -0.12518728]
# > <class 'numpy.ndarray'> (64, 2) [-0.22554937 -0.23586142]
# episode: 5   score: 16.0   memory length: 165   epsilon: 0.9360999518731578
# > <class 'numpy.ndarray'> (64, 2) [-0.07381211 -0.11095954]
# > <class 'numpy.ndarray'> (64, 2) [-0.4517127  -0.44019237]
# > <class 'numpy.ndarray'> (64, 2) [-0.43770766 -0.01538205]
# > <class 'numpy.ndarray'> (64, 2) [-0.2391915  -0.03214487]
# > <class 'numpy.ndarray'> (64, 2) [-0.0611649  -0.04891872]
# > <class 'numpy.ndarray'> (64, 2) [-0.49504501 -0.18384501]
# > <class 'numpy.ndarray'> (64, 2) [-0.09803822 -0.09781063]
# > <class 'numpy.ndarray'> (64, 2) [-0.64677876 -0.01864159]
# > <class 'numpy.ndarray'> (64, 2) [-0.49712074 -0.13938162]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00029261 -0.04508006]
# > <class 'numpy.ndarray'> (64, 2) [-0.16422738 -0.15448312]
# > <class 'numpy.ndarray'> (64, 2) [-0.24818926 -0.03247647]
# > <class 'numpy.ndarray'> (64, 2) [-0.46366924 -0.0260825 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.56471229 -0.00119291]
# > <class 'numpy.ndarray'> (64, 2) [-0.13630171 -0.10888186]
# > <class 'numpy.ndarray'> (64, 2) [-0.31213981  0.00692637]
# > <class 'numpy.ndarray'> (64, 2) [-0.04984751 -0.01973659]
# > <class 'numpy.ndarray'> (64, 2) [-0.40746209 -0.38643485]
# > <class 'numpy.ndarray'> (64, 2) [-0.24394913 -0.08663494]
# > <class 'numpy.ndarray'> (64, 2) [-0.31213981  0.00692637]
# > <class 'numpy.ndarray'> (64, 2) [-0.46698794  0.0346949 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.05021153 -0.01185473]
# > <class 'numpy.ndarray'> (64, 2) [-0.33965334 -0.31683379]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00449163 -0.04276572]
# > <class 'numpy.ndarray'> (64, 2) [-0.24726301 -0.2606377 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.46366924 -0.0260825 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.00609851 -0.0535203 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.42295045 -0.17335334]
# > <class 'numpy.ndarray'> (64, 2) [-0.56471229 -0.00119291]
# > <class 'numpy.ndarray'> (64, 2) [-0.3337101  -0.22791982]
# > <class 'numpy.ndarray'> (64, 2) [-0.42765072 -0.03267232]
# > <class 'numpy.ndarray'> (64, 2) [-0.46366924 -0.0260825 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.34793246 -0.40823799]
# episode: 6   score: 32.0   memory length: 198   epsilon: 0.9056978449586682
# > <class 'numpy.ndarray'> (64, 2) [ 0.04807295 -0.43693835]
# > <class 'numpy.ndarray'> (64, 2) [-0.49712074 -0.13938162]
# > <class 'numpy.ndarray'> (64, 2) [-0.1154043  -0.12850292]
# > <class 'numpy.ndarray'> (64, 2) [-0.0611649  -0.04891872]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00948037 -0.03897395]
# > <class 'numpy.ndarray'> (64, 2) [-0.04945055 -0.02436523]
# > <class 'numpy.ndarray'> (64, 2) [-0.2411104  -0.01716744]
# > <class 'numpy.ndarray'> (64, 2) [-0.40240249 -0.00120944]
# > <class 'numpy.ndarray'> (64, 2) [-0.2228411  -0.00501497]
# > <class 'numpy.ndarray'> (64, 2) [-0.25532266 -0.21546811]
# > <class 'numpy.ndarray'> (64, 2) [-0.1154043  -0.12850292]
# > <class 'numpy.ndarray'> (64, 2) [-0.06057519 -0.10981572]
# > <class 'numpy.ndarray'> (64, 2) [-0.07243665 -0.01279089]
# > <class 'numpy.ndarray'> (64, 2) [-0.29583412 -0.05582509]
# > <class 'numpy.ndarray'> (64, 2) [-0.76487815 -0.08918971]
# > <class 'numpy.ndarray'> (64, 2) [-0.16422738 -0.15448312]
# > <class 'numpy.ndarray'> (64, 2) [-0.22566405 -0.12110946]
# > <class 'numpy.ndarray'> (64, 2) [-0.2391915  -0.03214487]
# > <class 'numpy.ndarray'> (64, 2) [-0.50792313 -0.00526756]
# episode: 7   score: 18.0   memory length: 217   epsilon: 0.8886435861147077
# > <class 'numpy.ndarray'> (64, 2) [-0.33629984 -0.32157612]
# > <class 'numpy.ndarray'> (64, 2) [-0.06057519 -0.10981572]
# > <class 'numpy.ndarray'> (64, 2) [-0.23732817 -0.03435567]
# > <class 'numpy.ndarray'> (64, 2) [-0.14014058 -0.15604141]
# > <class 'numpy.ndarray'> (64, 2) [-0.50068748 -0.2118908 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.06057519 -0.10981572]
# > <class 'numpy.ndarray'> (64, 2) [-0.56471229 -0.00119291]
# > <class 'numpy.ndarray'> (64, 2) [-0.34793246 -0.40823799]
# > <class 'numpy.ndarray'> (64, 2) [-0.01507039 -0.01038669]
# > <class 'numpy.ndarray'> (64, 2) [-0.02952508 -0.04796745]
# > <class 'numpy.ndarray'> (64, 2) [-0.41655546  0.02535233]
# > <class 'numpy.ndarray'> (64, 2) [-0.04984751 -0.01973659]
# > <class 'numpy.ndarray'> (64, 2) [-1.029984   -0.06281167]
# > <class 'numpy.ndarray'> (64, 2) [-0.30376473 -0.12254754]
# > <class 'numpy.ndarray'> (64, 2) [-0.24187744  0.02334921]
# > <class 'numpy.ndarray'> (64, 2) [-0.22554937 -0.23586142]
# > <class 'numpy.ndarray'> (64, 2) [-0.26595491 -0.03257333]
# > <class 'numpy.ndarray'> (64, 2) [-0.40618074 -0.08593735]
# > <class 'numpy.ndarray'> (64, 2) [-0.16211346 -0.12658808]
# > <class 'numpy.ndarray'> (64, 2) [-0.20607397 -0.11717194]
# > <class 'numpy.ndarray'> (64, 2) [-0.527542   -0.22464918]
# episode: 8   score: 20.0   memory length: 238   epsilon: 0.8701675093639105
# > <class 'numpy.ndarray'> (64, 2) [-0.46278912 -0.16552606]
# > <class 'numpy.ndarray'> (64, 2) [-0.10795131 -0.38476747]
# > <class 'numpy.ndarray'> (64, 2) [-0.12970056 -0.1011776 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.24187744  0.02334921]
# > <class 'numpy.ndarray'> (64, 2) [-0.00609851 -0.0535203 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.01670049 -0.03014445]
# > <class 'numpy.ndarray'> (64, 2) [-0.08820908 -0.12091024]
# > <class 'numpy.ndarray'> (64, 2) [-0.14658491 -0.12888314]
# > <class 'numpy.ndarray'> (64, 2) [-0.4424538  -0.01396403]
# > <class 'numpy.ndarray'> (64, 2) [-0.26595491 -0.03257333]
# > <class 'numpy.ndarray'> (64, 2) [-0.25728261 -0.00986446]
# > <class 'numpy.ndarray'> (64, 2) [-0.49203235 -0.00217526]
# > <class 'numpy.ndarray'> (64, 2) [-0.1154043  -0.12850292]
# > <class 'numpy.ndarray'> (64, 2) [-0.0595291  -0.14165458]
# > <class 'numpy.ndarray'> (64, 2) [-0.3060118 -0.0755467]
# > <class 'numpy.ndarray'> (64, 2) [-0.06812648 -0.10851748]
# > <class 'numpy.ndarray'> (64, 2) [-0.09804159 -0.12832135]
# > <class 'numpy.ndarray'> (64, 2) [-0.25398782 -0.06826548]
# > <class 'numpy.ndarray'> (64, 2) [-0.1248479 -0.1343576]
# > <class 'numpy.ndarray'> (64, 2) [-0.15849766 -0.10887028]
# > <class 'numpy.ndarray'> (64, 2) [-0.71104866 -0.02038714]
# > <class 'numpy.ndarray'> (64, 2) [-0.49504501 -0.18384501]
# > <class 'numpy.ndarray'> (64, 2) [-0.50723332 -0.057173  ]
# episode: 9   score: 22.0   memory length: 261   epsilon: 0.8503722756378911
# > <class 'numpy.ndarray'> (64, 2) [-0.56311369 -0.27637449]
# > <class 'numpy.ndarray'> (64, 2) [-0.05021153 -0.01185473]
# > <class 'numpy.ndarray'> (64, 2) [-0.3337101  -0.22791982]
# > <class 'numpy.ndarray'> (64, 2) [-0.58121598 -0.14738101]
# > <class 'numpy.ndarray'> (64, 2) [-0.22566405 -0.12110946]
# > <class 'numpy.ndarray'> (64, 2) [-0.06057519 -0.10981572]
# > <class 'numpy.ndarray'> (64, 2) [-0.30196226 -0.16512567]
# > <class 'numpy.ndarray'> (64, 2) [-0.1329014  -0.12572308]
# > <class 'numpy.ndarray'> (64, 2) [-0.58628547  0.02218547]
# > <class 'numpy.ndarray'> (64, 2) [-0.30417693 -0.04581286]
# > <class 'numpy.ndarray'> (64, 2) [-0.68820149 -0.69170612]
# > <class 'numpy.ndarray'> (64, 2) [-0.11580379 -0.12518728]
# > <class 'numpy.ndarray'> (64, 2) [-0.39587864 -0.13132669]
# > <class 'numpy.ndarray'> (64, 2) [-0.64677876 -0.01864159]
# > <class 'numpy.ndarray'> (64, 2) [-0.87512898 -0.03757912]
# > <class 'numpy.ndarray'> (64, 2) [-0.07009337 -0.03571554]
# > <class 'numpy.ndarray'> (64, 2) [-0.40618074 -0.08593735]
# > <class 'numpy.ndarray'> (64, 2) [-0.28980154 -0.00357166]
# > <class 'numpy.ndarray'> (64, 2) [-0.04675858 -0.03154506]
# > <class 'numpy.ndarray'> (64, 2) [-0.30417693 -0.04581286]
# > <class 'numpy.ndarray'> (64, 2) [-0.46278912 -0.16552606]
# > <class 'numpy.ndarray'> (64, 2) [-0.06812648 -0.10851748]
# > <class 'numpy.ndarray'> (64, 2) [-0.82556391 -0.80421269]
# > <class 'numpy.ndarray'> (64, 2) [-0.28297955 -0.24603878]
# > <class 'numpy.ndarray'> (64, 2) [-0.76487815 -0.08918971]
# > <class 'numpy.ndarray'> (64, 2) [-0.45887339 -0.13587314]
# > <class 'numpy.ndarray'> (64, 2) [ 0.02942964 -0.22047502]
# > <class 'numpy.ndarray'> (64, 2) [-0.11822213 -0.11978769]
# > <class 'numpy.ndarray'> (64, 2) [-0.30196226 -0.16512567]
# > <class 'numpy.ndarray'> (64, 2) [-0.0309663 -0.114516 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.51679802 -0.19128802]
# > <class 'numpy.ndarray'> (64, 2) [-0.16422738 -0.15448312]
# episode: 10   score: 31.0   memory length: 293   epsilon: 0.8235779600286178
# > <class 'numpy.ndarray'> (64, 2) [-0.04018756 -0.01535746]
# > <class 'numpy.ndarray'> (64, 2) [-0.08152579 -0.00318106]
# > <class 'numpy.ndarray'> (64, 2) [-0.0611649  -0.04891872]
# > <class 'numpy.ndarray'> (64, 2) [-0.76487815 -0.08918971]
# > <class 'numpy.ndarray'> (64, 2) [-0.04406973 -0.01116045]
# > <class 'numpy.ndarray'> (64, 2) [-0.14014058 -0.15604141]
# > <class 'numpy.ndarray'> (64, 2) [-0.36022243 -0.34410095]
# > <class 'numpy.ndarray'> (64, 2) [-0.00758039 -0.11103573]
# > <class 'numpy.ndarray'> (64, 2) [ 0.01065582 -0.27389932]
# > <class 'numpy.ndarray'> (64, 2) [-0.29078329 -0.13976462]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00029261 -0.04508006]
# > <class 'numpy.ndarray'> (64, 2) [-0.13445738 -0.12612669]
# > <class 'numpy.ndarray'> (64, 2) [-0.42295045 -0.17335334]
# > <class 'numpy.ndarray'> (64, 2) [-0.24483874 -0.22731964]
# > <class 'numpy.ndarray'> (64, 2) [-0.08542935 -0.0332485 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.5652315  -0.07556787]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00029261 -0.04508006]
# > <class 'numpy.ndarray'> (64, 2) [-0.22092083  0.00101952]
# > <class 'numpy.ndarray'> (64, 2) [-0.33977044  0.00044233]
# > <class 'numpy.ndarray'> (64, 2) [-0.34793246 -0.40823799]
# > <class 'numpy.ndarray'> (64, 2) [-0.82989788 -0.83911574]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00313212 -0.25739598]
# > <class 'numpy.ndarray'> (64, 2) [-0.82556391 -0.80421269]
# > <class 'numpy.ndarray'> (64, 2) [-0.64677876 -0.01864159]
# > <class 'numpy.ndarray'> (64, 2) [-0.23916194 -0.03246547]
# > <class 'numpy.ndarray'> (64, 2) [-0.32395625  0.03144726]
# > <class 'numpy.ndarray'> (64, 2) [-0.00401044 -0.20328444]
# > <class 'numpy.ndarray'> (64, 2) [-0.4732585  -0.00986911]
# > <class 'numpy.ndarray'> (64, 2) [-0.24187744  0.02334921]
# > <class 'numpy.ndarray'> (64, 2) [-0.54422623 -0.00382726]
# > <class 'numpy.ndarray'> (64, 2) [-0.26546773 -0.26078549]
# > <class 'numpy.ndarray'> (64, 2) [-0.1154043  -0.12850292]
# > <class 'numpy.ndarray'> (64, 2) [-0.22092083  0.00101952]
# > <class 'numpy.ndarray'> (64, 2) [-0.3721875  -0.00336412]
# > <class 'numpy.ndarray'> (64, 2) [-0.3337101  -0.22791982]
# > <class 'numpy.ndarray'> (64, 2) [-0.00110111 -0.06369971]
# > <class 'numpy.ndarray'> (64, 2) [-0.01901731 -0.10443071]
# > <class 'numpy.ndarray'> (64, 2) [-0.32395625  0.03144726]
# > <class 'numpy.ndarray'> (64, 2) [-0.5652315  -0.07556787]
# > <class 'numpy.ndarray'> (64, 2) [-0.46278912 -0.16552606]
# > <class 'numpy.ndarray'> (64, 2) [-0.24590756 -0.23785427]
# episode: 11   score: 40.0   memory length: 334   epsilon: 0.790477901043851
# > <class 'numpy.ndarray'> (64, 2) [-0.20388871 -0.20163764]
# > <class 'numpy.ndarray'> (64, 2) [-0.29078329 -0.13976462]
# > <class 'numpy.ndarray'> (64, 2) [-0.68474382 -0.66026318]
# > <class 'numpy.ndarray'> (64, 2) [-0.42765072 -0.03267232]
# > <class 'numpy.ndarray'> (64, 2) [-0.00949684 -0.1374816 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.11452703 -0.11402257]
# > <class 'numpy.ndarray'> (64, 2) [-0.38973191 -0.36877704]
# > <class 'numpy.ndarray'> (64, 2) [-0.00823602 -0.03321005]
# > <class 'numpy.ndarray'> (64, 2) [-0.09109242 -0.00260091]
# > <class 'numpy.ndarray'> (64, 2) [-0.81482482 -0.78286785]
# > <class 'numpy.ndarray'> (64, 2) [-0.40746209 -0.38643485]
# > <class 'numpy.ndarray'> (64, 2) [-0.02952508 -0.04796745]
# > <class 'numpy.ndarray'> (64, 2) [-0.14341384 -0.10589848]
# episode: 12   score: 12.0   memory length: 347   epsilon: 0.7802631200940584
# > <class 'numpy.ndarray'> (64, 2) [-0.28681687 -0.03642845]
# > <class 'numpy.ndarray'> (64, 2) [-0.48301053 -0.10402837]
# > <class 'numpy.ndarray'> (64, 2) [-0.13421795 -0.0249491 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.849518   -0.87889135]
# > <class 'numpy.ndarray'> (64, 2) [-0.0416159  -0.03189812]
# > <class 'numpy.ndarray'> (64, 2) [-0.25398782 -0.06826548]
# > <class 'numpy.ndarray'> (64, 2) [-0.01670049 -0.03014445]
# > <class 'numpy.ndarray'> (64, 2) [-0.22554937 -0.23586142]
# > <class 'numpy.ndarray'> (64, 2) [-0.0309663 -0.114516 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.54422623 -0.00382726]
# > <class 'numpy.ndarray'> (64, 2) [-0.3060118 -0.0755467]
# > <class 'numpy.ndarray'> (64, 2) [-0.20388871 -0.20163764]
# > <class 'numpy.ndarray'> (64, 2) [-0.39298671 -0.39332709]
# > <class 'numpy.ndarray'> (64, 2) [-0.00459522 -0.01759424]
# > <class 'numpy.ndarray'> (64, 2) [-0.16171291 -0.2223551 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.0416159  -0.03189812]
# > <class 'numpy.ndarray'> (64, 2) [-0.38640076  0.02085849]
# episode: 13   score: 16.0   memory length: 364   epsilon: 0.7671042341100781
# > <class 'numpy.ndarray'> (64, 2) [-0.00609851 -0.0535203 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.55242181 -0.23970857]
# > <class 'numpy.ndarray'> (64, 2) [-0.13475233 -0.10250361]
# > <class 'numpy.ndarray'> (64, 2) [-0.03375101 -0.01350038]
# > <class 'numpy.ndarray'> (64, 2) [-0.30376473 -0.12254754]
# > <class 'numpy.ndarray'> (64, 2) [-0.87512898 -0.03757912]
# > <class 'numpy.ndarray'> (64, 2) [-0.12970056 -0.1011776 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.02965415 -0.01752287]
# > <class 'numpy.ndarray'> (64, 2) [-0.27507028 -0.25467476]
# > <class 'numpy.ndarray'> (64, 2) [-0.64677876 -0.01864159]
# > <class 'numpy.ndarray'> (64, 2) [-0.25182605 -0.23117758]
# > <class 'numpy.ndarray'> (64, 2) [-0.54422623 -0.00382726]
# > <class 'numpy.ndarray'> (64, 2) [-0.68942142 -0.13771404]
# > <class 'numpy.ndarray'> (64, 2) [-0.23180565  0.00048129]
# episode: 14   score: 13.0   memory length: 378   epsilon: 0.7564343028582378
# > <class 'numpy.ndarray'> (64, 2) [-0.58121598 -0.14738101]
# > <class 'numpy.ndarray'> (64, 2) [-0.32214326 -0.17062354]
# > <class 'numpy.ndarray'> (64, 2) [-0.1329014  -0.12572308]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00449163 -0.04276572]
# > <class 'numpy.ndarray'> (64, 2) [-0.26927614 -0.1464549 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.41682783 -0.05466685]
# > <class 'numpy.ndarray'> (64, 2) [-0.02965415 -0.01752287]
# > <class 'numpy.ndarray'> (64, 2) [-0.11851103 -0.01008178]
# > <class 'numpy.ndarray'> (64, 2) [-0.15849766 -0.10887028]
# > <class 'numpy.ndarray'> (64, 2) [-0.2830129  -0.03221554]
# > <class 'numpy.ndarray'> (64, 2) [-0.16422738 -0.15448312]
# > <class 'numpy.ndarray'> (64, 2) [-0.22972402 -0.21458213]
# > <class 'numpy.ndarray'> (64, 2) [-0.41655546  0.02535233]
# > <class 'numpy.ndarray'> (64, 2) [-0.80982804 -0.07479137]
# > <class 'numpy.ndarray'> (64, 2) [-0.15253085  0.02527267]
# > <class 'numpy.ndarray'> (64, 2) [-0.81482482 -0.78286785]
# > <class 'numpy.ndarray'> (64, 2) [-0.15681611 -0.15740938]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00208432 -0.10999849]
# > <class 'numpy.ndarray'> (64, 2) [-0.39400434 -0.02396296]
# > <class 'numpy.ndarray'> (64, 2) [-0.76487815 -0.08918971]
# > <class 'numpy.ndarray'> (64, 2) [-0.03881148 -0.11144732]
# > <class 'numpy.ndarray'> (64, 2) [-0.0611649  -0.04891872]
# > <class 'numpy.ndarray'> (64, 2) [-0.22972402 -0.21458213]
# > <class 'numpy.ndarray'> (64, 2) [-0.1248479 -0.1343576]
# > <class 'numpy.ndarray'> (64, 2) [-0.10509427 -0.11983375]
# > <class 'numpy.ndarray'> (64, 2) [-0.41991854 -0.13233098]
# > <class 'numpy.ndarray'> (64, 2) [-0.13992749 -0.0551949 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.16044024 -0.18275334]
# > <class 'numpy.ndarray'> (64, 2) [-0.04114443 -0.03567965]
# > <class 'numpy.ndarray'> (64, 2) [-0.37372574  0.01248026]
# > <class 'numpy.ndarray'> (64, 2) [-0.80982804 -0.07479137]
# episode: 15   score: 30.0   memory length: 409   epsilon: 0.7333332049215037
# > <class 'numpy.ndarray'> (64, 2) [-0.20996532  0.01782673]
# > <class 'numpy.ndarray'> (64, 2) [-0.03387721 -0.25221664]
# > <class 'numpy.ndarray'> (64, 2) [-0.41682783 -0.05466685]
# > <class 'numpy.ndarray'> (64, 2) [-0.01484243 -0.30006558]
# > <class 'numpy.ndarray'> (64, 2) [-0.04250928 -0.02525792]
# > <class 'numpy.ndarray'> (64, 2) [-0.32214326 -0.17062354]
# > <class 'numpy.ndarray'> (64, 2) [-0.14341384 -0.10589848]
# > <class 'numpy.ndarray'> (64, 2) [-0.26743832 -0.26511046]
# > <class 'numpy.ndarray'> (64, 2) [-0.00949684 -0.1374816 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.03387721 -0.25221664]
# > <class 'numpy.ndarray'> (64, 2) [-0.15681611 -0.15740938]
# > <class 'numpy.ndarray'> (64, 2) [-0.5618977  -0.58140242]
# > <class 'numpy.ndarray'> (64, 2) [-0.08498558 -0.03399424]
# > <class 'numpy.ndarray'> (64, 2) [-0.58743119 -0.09916863]
# > <class 'numpy.ndarray'> (64, 2) [-0.5603705  -0.56336629]
# > <class 'numpy.ndarray'> (64, 2) [-0.09109242 -0.00260091]
# > <class 'numpy.ndarray'> (64, 2) [-0.48301053 -0.10402837]
# > <class 'numpy.ndarray'> (64, 2) [-0.11932804 -0.11926   ]
# > <class 'numpy.ndarray'> (64, 2) [-0.20785758 -0.02258696]
# episode: 16   score: 18.0   memory length: 428   epsilon: 0.7195245662400531
# > <class 'numpy.ndarray'> (64, 2) [-0.13690864 -0.17835057]
# > <class 'numpy.ndarray'> (64, 2) [-0.96863455 -0.96854955]
# > <class 'numpy.ndarray'> (64, 2) [-0.09381217 -0.031298  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.33629984 -0.32157612]
# > <class 'numpy.ndarray'> (64, 2) [-0.12119748  0.03856026]
# > <class 'numpy.ndarray'> (64, 2) [-0.43770766 -0.01538205]
# > <class 'numpy.ndarray'> (64, 2) [-0.01497047 -0.13801721]
# > <class 'numpy.ndarray'> (64, 2) [-0.11822213 -0.11978769]
# > <class 'numpy.ndarray'> (64, 2) [-0.30417693 -0.04581286]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00208432 -0.10999849]
# > <class 'numpy.ndarray'> (64, 2) [-0.32214326 -0.17062354]
# > <class 'numpy.ndarray'> (64, 2) [-0.50723332 -0.057173  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.09800619 -0.14989465]
# > <class 'numpy.ndarray'> (64, 2) [-0.03080168 -0.06008133]
# > <class 'numpy.ndarray'> (64, 2) [-0.39547515 -0.39237598]
# > <class 'numpy.ndarray'> (64, 2) [-0.19157043 -0.00772656]
# > <class 'numpy.ndarray'> (64, 2) [-0.5618977  -0.58140242]
# > <class 'numpy.ndarray'> (64, 2) [-0.5419386  -0.53181326]
# > <class 'numpy.ndarray'> (64, 2) [-0.15942174 -0.12049141]
# > <class 'numpy.ndarray'> (64, 2) [-0.48301053 -0.10402837]
# > <class 'numpy.ndarray'> (64, 2) [-0.15854099 -0.13801096]
# > <class 'numpy.ndarray'> (64, 2) [-0.03375101 -0.01350038]
# > <class 'numpy.ndarray'> (64, 2) [-0.14172837 -0.24061874]
# > <class 'numpy.ndarray'> (64, 2) [-0.18776885 -0.08917111]
# > <class 'numpy.ndarray'> (64, 2) [-0.13445738 -0.12612669]
# episode: 17   score: 24.0   memory length: 453   epsilon: 0.7017506636113059
# > <class 'numpy.ndarray'> (64, 2) [-0.0611649  -0.04891872]
# > <class 'numpy.ndarray'> (64, 2) [-0.5371632  -0.54692453]
# > <class 'numpy.ndarray'> (64, 2) [-0.05289286 -0.0241195 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.01627272 -0.33150426]
# > <class 'numpy.ndarray'> (64, 2) [-0.04250928 -0.02525792]
# > <class 'numpy.ndarray'> (64, 2) [-0.04159463 -0.00976804]
# > <class 'numpy.ndarray'> (64, 2) [-0.09804159 -0.12832135]
# > <class 'numpy.ndarray'> (64, 2) [-0.3721875  -0.00336412]
# > <class 'numpy.ndarray'> (64, 2) [-0.30196226 -0.16512567]
# > <class 'numpy.ndarray'> (64, 2) [-0.00443461 -0.08013958]
# > <class 'numpy.ndarray'> (64, 2) [-0.01507039 -0.01038669]
# > <class 'numpy.ndarray'> (64, 2) [-0.57166195 -0.06260219]
# > <class 'numpy.ndarray'> (64, 2) [-0.11851103 -0.01008178]
# episode: 18   score: 12.0   memory length: 466   epsilon: 0.6926824413362807
# > <class 'numpy.ndarray'> (64, 2) [-0.57570577 -0.01488592]
# > <class 'numpy.ndarray'> (64, 2) [-0.01484243 -0.30006558]
# > <class 'numpy.ndarray'> (64, 2) [-0.39400434 -0.02396296]
# > <class 'numpy.ndarray'> (64, 2) [-0.31879315 -0.11963806]
# > <class 'numpy.ndarray'> (64, 2) [-0.1738787  -0.01338473]
# > <class 'numpy.ndarray'> (64, 2) [-0.26145554 -0.04423679]
# > <class 'numpy.ndarray'> (64, 2) [-0.14737213  0.03078786]
# > <class 'numpy.ndarray'> (64, 2) [-0.15296555 -0.15072685]
# > <class 'numpy.ndarray'> (64, 2) [-0.10515155 -0.19742052]
# > <class 'numpy.ndarray'> (64, 2) [-0.26595491 -0.03257333]
# > <class 'numpy.ndarray'> (64, 2) [-0.03881148 -0.11144732]
# > <class 'numpy.ndarray'> (64, 2) [-0.14737213  0.03078786]
# > <class 'numpy.ndarray'> (64, 2) [-0.2886664 -0.2945157]
# > <class 'numpy.ndarray'> (64, 2) [-0.09803822 -0.09781063]
# > <class 'numpy.ndarray'> (64, 2) [-0.00289345 -0.03685044]
# > <class 'numpy.ndarray'> (64, 2) [-0.73903519 -0.03865942]
# > <class 'numpy.ndarray'> (64, 2) [-0.58628547  0.02218547]
# > <class 'numpy.ndarray'> (64, 2) [-0.5807249  -0.43199003]
# > <class 'numpy.ndarray'> (64, 2) [-0.03515396 -0.12132995]
# > <class 'numpy.ndarray'> (64, 2) [-0.04316459 -0.02648935]
# > <class 'numpy.ndarray'> (64, 2) [-0.03515396 -0.12132995]
# > <class 'numpy.ndarray'> (64, 2) [-0.80982804 -0.07479137]
# > <class 'numpy.ndarray'> (64, 2) [-0.06608663 -0.11021072]
# > <class 'numpy.ndarray'> (64, 2) [-0.05142007 -0.02122422]
# > <class 'numpy.ndarray'> (64, 2) [-0.33757919  0.006328  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.19551189 -0.19782755]
# > <class 'numpy.ndarray'> (64, 2) [-0.01670049 -0.03014445]
# > <class 'numpy.ndarray'> (64, 2) [-0.16134495  0.00737441]
# > <class 'numpy.ndarray'> (64, 2) [-0.01901731 -0.10443071]
# > <class 'numpy.ndarray'> (64, 2) [-0.26432681 -0.24361828]
# > <class 'numpy.ndarray'> (64, 2) [-0.09804159 -0.12832135]
# > <class 'numpy.ndarray'> (64, 2) [-0.02478015 -0.00227463]
# > <class 'numpy.ndarray'> (64, 2) [-0.47718838 -0.06450136]
# > <class 'numpy.ndarray'> (64, 2) [-0.50181574 -0.47885358]
# > <class 'numpy.ndarray'> (64, 2) [-0.57570577 -0.01488592]
# episode: 19   score: 34.0   memory length: 501   epsilon: 0.6688462043806328
# > <class 'numpy.ndarray'> (64, 2) [-0.29613504 -0.29962942]
# > <class 'numpy.ndarray'> (64, 2) [-0.26095766 -0.1331102 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.08284631 -0.10445548]
# > <class 'numpy.ndarray'> (64, 2) [-0.30417693 -0.04581286]
# > <class 'numpy.ndarray'> (64, 2) [-0.29613504 -0.29962942]
# > <class 'numpy.ndarray'> (64, 2) [-0.38973191 -0.36877704]
# > <class 'numpy.ndarray'> (64, 2) [-0.48814064 -0.01169476]
# > <class 'numpy.ndarray'> (64, 2) [-0.80982804 -0.07479137]
# > <class 'numpy.ndarray'> (64, 2) [-0.42118394 -0.39628464]
# > <class 'numpy.ndarray'> (64, 2) [-0.00390231 -0.07089983]
# > <class 'numpy.ndarray'> (64, 2) [-0.50068748 -0.2118908 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.06608663 -0.11021072]
# > <class 'numpy.ndarray'> (64, 2) [-0.33965334 -0.31683379]
# > <class 'numpy.ndarray'> (64, 2) [-0.30376473 -0.12254754]
# > <class 'numpy.ndarray'> (64, 2) [-0.00443461 -0.08013958]
# > <class 'numpy.ndarray'> (64, 2) [-0.41991854 -0.13233098]
# > <class 'numpy.ndarray'> (64, 2) [-0.40860009 -0.35751095]
# > <class 'numpy.ndarray'> (64, 2) [-0.03425629 -0.01159928]
# > <class 'numpy.ndarray'> (64, 2) [-0.37999603 -0.02769923]
# > <class 'numpy.ndarray'> (64, 2) [-0.12992927 -0.00089794]
# > <class 'numpy.ndarray'> (64, 2) [-0.41576102 -0.46672928]
# episode: 20   score: 20.0   memory length: 522   epsilon: 0.654940006215578
# > <class 'numpy.ndarray'> (64, 2) [-0.43748629  0.01700506]
# > <class 'numpy.ndarray'> (64, 2) [-0.18776885 -0.08917111]
# > <class 'numpy.ndarray'> (64, 2) [-0.28837657 -0.23197217]
# > <class 'numpy.ndarray'> (64, 2) [-0.10294535 -0.28613526]
# > <class 'numpy.ndarray'> (64, 2) [-0.15424348 -0.16261902]
# > <class 'numpy.ndarray'> (64, 2) [-0.527542   -0.22464918]
# > <class 'numpy.ndarray'> (64, 2) [-0.04018756 -0.01535746]
# > <class 'numpy.ndarray'> (64, 2) [-0.59443426 -0.0718556 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.20300148  0.02340096]
# > <class 'numpy.ndarray'> (64, 2) [-0.51679802 -0.19128802]
# > <class 'numpy.ndarray'> (64, 2) [-0.12629208  0.00677864]
# > <class 'numpy.ndarray'> (64, 2) [-0.48092216 -0.40468407]
# episode: 21   score: 11.0   memory length: 534   epsilon: 0.647123808418277
# > <class 'numpy.ndarray'> (64, 2) [-0.3345128  -0.12828302]
# > <class 'numpy.ndarray'> (64, 2) [-0.40026647 -0.35181582]
# > <class 'numpy.ndarray'> (64, 2) [-0.01901731 -0.10443071]
# > <class 'numpy.ndarray'> (64, 2) [-0.09381217 -0.031298  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.16044024 -0.18275334]
# > <class 'numpy.ndarray'> (64, 2) [-0.00694976 -0.03165462]
# > <class 'numpy.ndarray'> (64, 2) [-0.27681994 -0.25255921]
# > <class 'numpy.ndarray'> (64, 2) [-0.5603705  -0.56336629]
# > <class 'numpy.ndarray'> (64, 2) [-0.24394913 -0.08663494]
# > <class 'numpy.ndarray'> (64, 2) [-0.61453193 -0.55546606]
# > <class 'numpy.ndarray'> (64, 2) [-0.12496614 -0.1283063 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.81482482 -0.78286785]
# > <class 'numpy.ndarray'> (64, 2) [-0.50723332 -0.057173  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.18916763  0.02373135]
# > <class 'numpy.ndarray'> (64, 2) [-0.45882893 -0.05391544]
# > <class 'numpy.ndarray'> (64, 2) [-0.33965334 -0.31683379]
# > <class 'numpy.ndarray'> (64, 2) [-0.61453193 -0.55546606]
# > <class 'numpy.ndarray'> (64, 2) [-0.14658491 -0.12888314]
# episode: 22   score: 17.0   memory length: 552   epsilon: 0.6355740637310745
# > <class 'numpy.ndarray'> (64, 2) [-0.15942174 -0.12049141]
# > <class 'numpy.ndarray'> (64, 2) [-0.7917949  -0.76117182]
# > <class 'numpy.ndarray'> (64, 2) [-0.36454946 -0.00289887]
# > <class 'numpy.ndarray'> (64, 2) [-0.08498558 -0.03399424]
# > <class 'numpy.ndarray'> (64, 2) [-0.25532266 -0.21546811]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00449163 -0.04276572]
# > <class 'numpy.ndarray'> (64, 2) [-0.29592103  0.03998795]
# > <class 'numpy.ndarray'> (64, 2) [-0.02256851 -0.05839518]
# > <class 'numpy.ndarray'> (64, 2) [-0.43054008 -0.41193211]
# > <class 'numpy.ndarray'> (64, 2) [-0.7318573  -0.73511404]
# > <class 'numpy.ndarray'> (64, 2) [-0.2234751  -0.01504263]
# > <class 'numpy.ndarray'> (64, 2) [-0.34822491 -0.29300737]
# > <class 'numpy.ndarray'> (64, 2) [-0.07494394 -0.12823577]
# > <class 'numpy.ndarray'> (64, 2) [-0.849518   -0.87889135]
# > <class 'numpy.ndarray'> (64, 2) [-0.10795131 -0.38476747]
# > <class 'numpy.ndarray'> (64, 2) [-0.54422623 -0.00382726]
# > <class 'numpy.ndarray'> (64, 2) [-0.12862399 -0.19627193]
# > <class 'numpy.ndarray'> (64, 2) [-0.70490545 -0.21149009]
# > <class 'numpy.ndarray'> (64, 2) [-0.24028979 -0.1376839 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.30417693 -0.04581286]
# > <class 'numpy.ndarray'> (64, 2) [-0.68146229 -0.20195256]
# > <class 'numpy.ndarray'> (64, 2) [-0.40746209 -0.38643485]
# > <class 'numpy.ndarray'> (64, 2) [-0.14172837 -0.24061874]
# > <class 'numpy.ndarray'> (64, 2) [-0.3691141  -0.23095387]
# > <class 'numpy.ndarray'> (64, 2) [ 0.01699677 -0.21825692]
# > <class 'numpy.ndarray'> (64, 2) [-0.49810123 -0.18839854]
# > <class 'numpy.ndarray'> (64, 2) [-0.23180565  0.00048129]
# > <class 'numpy.ndarray'> (64, 2) [-0.42350626 -0.12133136]
# > <class 'numpy.ndarray'> (64, 2) [-0.00823602 -0.03321005]
# episode: 23   score: 28.0   memory length: 581   epsilon: 0.6173981515854621
# > <class 'numpy.ndarray'> (64, 2) [-0.7019853  -0.69970977]
# > <class 'numpy.ndarray'> (64, 2) [-0.12620391 -0.13544793]
# > <class 'numpy.ndarray'> (64, 2) [-0.04945055 -0.02436523]
# > <class 'numpy.ndarray'> (64, 2) [-0.31213981  0.00692637]
# > <class 'numpy.ndarray'> (64, 2) [-0.08284631 -0.10445548]
# > <class 'numpy.ndarray'> (64, 2) [-0.46278912 -0.16552606]
# > <class 'numpy.ndarray'> (64, 2) [-0.05021153 -0.01185473]
# > <class 'numpy.ndarray'> (64, 2) [-0.16644898 -0.11889029]
# > <class 'numpy.ndarray'> (64, 2) [-0.24726301 -0.2606377 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.00459522 -0.01759424]
# > <class 'numpy.ndarray'> (64, 2) [-0.14014058 -0.15604141]
# > <class 'numpy.ndarray'> (64, 2) [-0.80982804 -0.07479137]
# > <class 'numpy.ndarray'> (64, 2) [-0.70490545 -0.21149009]
# > <class 'numpy.ndarray'> (64, 2) [-0.16964388 -0.0367308 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.40618074 -0.08593735]
# > <class 'numpy.ndarray'> (64, 2) [-0.65764713 -0.09174016]
# > <class 'numpy.ndarray'> (64, 2) [-0.26624212 -0.2293354 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.03419892 -0.00149389]
# > <class 'numpy.ndarray'> (64, 2) [-0.19551189 -0.19782755]
# > <class 'numpy.ndarray'> (64, 2) [-0.50279945 -0.04339236]
# > <class 'numpy.ndarray'> (64, 2) [-0.71104866 -0.02038714]
# > <class 'numpy.ndarray'> (64, 2) [-0.48092216 -0.40468407]
# > <class 'numpy.ndarray'> (64, 2) [-0.26553863 -0.23628843]
# > <class 'numpy.ndarray'> (64, 2) [-0.00505893 -0.03388352]
# > <class 'numpy.ndarray'> (64, 2) [-0.58628547  0.02218547]
# > <class 'numpy.ndarray'> (64, 2) [-0.13475233 -0.10250361]
# > <class 'numpy.ndarray'> (64, 2) [-0.23910208 -0.10382835]
# > <class 'numpy.ndarray'> (64, 2) [-0.10515155 -0.19742052]
# > <class 'numpy.ndarray'> (64, 2) [-0.26764733  0.0004048 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.42350626 -0.12133136]
# > <class 'numpy.ndarray'> (64, 2) [-0.32421058 -0.06411113]
# > <class 'numpy.ndarray'> (64, 2) [-0.79206872 -0.04011229]
# > <class 'numpy.ndarray'> (64, 2) [-0.0235879  -0.01026877]
# episode: 24   score: 32.0   memory length: 614   epsilon: 0.5973466554009469
# > <class 'numpy.ndarray'> (64, 2) [-0.67523396 -0.0130778 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.04159463 -0.00976804]
# > <class 'numpy.ndarray'> (64, 2) [-0.26432681 -0.24361828]
# > <class 'numpy.ndarray'> (64, 2) [-0.00401044 -0.20328444]
# > <class 'numpy.ndarray'> (64, 2) [-0.12602796 -0.13323998]
# > <class 'numpy.ndarray'> (64, 2) [-0.50723332 -0.057173  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.17019248 -0.14461496]
# > <class 'numpy.ndarray'> (64, 2) [-0.01901731 -0.10443071]
# > <class 'numpy.ndarray'> (64, 2) [-1.029984   -0.06281167]
# > <class 'numpy.ndarray'> (64, 2) [ 0.04807295 -0.43693835]
# > <class 'numpy.ndarray'> (64, 2) [-0.09381217 -0.031298  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.04945055 -0.02436523]
# > <class 'numpy.ndarray'> (64, 2) [-0.50723332 -0.057173  ]
# episode: 25   score: 12.0   memory length: 627   epsilon: 0.5896275715050474
# > <class 'numpy.ndarray'> (64, 2) [-0.02216223 -0.04219145]
# > <class 'numpy.ndarray'> (64, 2) [-0.33970273  0.03076595]
# > <class 'numpy.ndarray'> (64, 2) [-0.19551189 -0.19782755]
# > <class 'numpy.ndarray'> (64, 2) [-0.25182605 -0.23117758]
# > <class 'numpy.ndarray'> (64, 2) [-0.04568549 -0.31422049]
# > <class 'numpy.ndarray'> (64, 2) [-0.10196373  0.00579298]
# > <class 'numpy.ndarray'> (64, 2) [-0.41576102 -0.46672928]
# > <class 'numpy.ndarray'> (64, 2) [-0.28467312 -0.26621732]
# > <class 'numpy.ndarray'> (64, 2) [-0.16561268 -0.10819203]
# > <class 'numpy.ndarray'> (64, 2) [-0.35264915 -0.22396693]
# > <class 'numpy.ndarray'> (64, 2) [-0.15665153 -0.01723331]
# > <class 'numpy.ndarray'> (64, 2) [-0.41260269 -0.01493207]
# > <class 'numpy.ndarray'> (64, 2) [-0.42749524 -0.42972577]
# > <class 'numpy.ndarray'> (64, 2) [-0.19157043 -0.00772656]
# > <class 'numpy.ndarray'> (64, 2) [-0.3222146   0.05329768]
# > <class 'numpy.ndarray'> (64, 2) [-0.71105206 -0.5826332 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.28127056 -0.13513172]
# > <class 'numpy.ndarray'> (64, 2) [-0.03471369 -0.03449783]
# > <class 'numpy.ndarray'> (64, 2) [-0.19758984 -0.02705829]
# > <class 'numpy.ndarray'> (64, 2) [-0.16435398 -0.14906932]
# > <class 'numpy.ndarray'> (64, 2) [-0.03085499 -0.0487747 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.04780019 -0.01481071]
# > <class 'numpy.ndarray'> (64, 2) [-0.33970273  0.03076595]
# > <class 'numpy.ndarray'> (64, 2) [-0.1860593  -0.04248554]
# > <class 'numpy.ndarray'> (64, 2) [-0.17823225 -0.1652588 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.46179724 -0.08295783]
# > <class 'numpy.ndarray'> (64, 2) [-0.25728261 -0.00986446]
# > <class 'numpy.ndarray'> (64, 2) [-0.39741698 -0.28719854]
# > <class 'numpy.ndarray'> (64, 2) [-0.82186806 -0.81375659]
# episode: 26   score: 28.0   memory length: 656   epsilon: 0.572765620160788
# > <class 'numpy.ndarray'> (64, 2) [-0.19157043 -0.00772656]
# > <class 'numpy.ndarray'> (64, 2) [-0.39278501 -0.32363129]
# > <class 'numpy.ndarray'> (64, 2) [-0.24394913 -0.08663494]
# > <class 'numpy.ndarray'> (64, 2) [-0.26095766 -0.1331102 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.65713429 -0.11792669]
# > <class 'numpy.ndarray'> (64, 2) [-0.37999603 -0.02769923]
# > <class 'numpy.ndarray'> (64, 2) [-0.2198216   0.06609661]
# > <class 'numpy.ndarray'> (64, 2) [-0.48814064 -0.01169476]
# > <class 'numpy.ndarray'> (64, 2) [-0.38179478 -0.02690203]
# > <class 'numpy.ndarray'> (64, 2) [-0.0392509  -0.17923762]
# > <class 'numpy.ndarray'> (64, 2) [-0.02946918 -0.0084115 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.00694976 -0.03165462]
# > <class 'numpy.ndarray'> (64, 2) [-0.29078329 -0.13976462]
# > <class 'numpy.ndarray'> (64, 2) [-0.30615115 -0.17143662]
# > <class 'numpy.ndarray'> (64, 2) [-0.05262055 -0.10579325]
# > <class 'numpy.ndarray'> (64, 2) [-0.00809767 -0.0343395 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.1804737  -0.12600502]
# > <class 'numpy.ndarray'> (64, 2) [-0.56886095 -0.25302541]
# > <class 'numpy.ndarray'> (64, 2) [-0.54551935 -0.52127278]
# > <class 'numpy.ndarray'> (64, 2) [-0.04945055 -0.02436523]
# > <class 'numpy.ndarray'> (64, 2) [-0.26145554 -0.04423679]
# > <class 'numpy.ndarray'> (64, 2) [-0.5371632  -0.54692453]
# > <class 'numpy.ndarray'> (64, 2) [-0.40536991 -0.00073957]
# > <class 'numpy.ndarray'> (64, 2) [-0.29592103  0.03998795]
# > <class 'numpy.ndarray'> (64, 2) [-0.28681687 -0.03642845]
# > <class 'numpy.ndarray'> (64, 2) [-0.02965415 -0.01752287]
# > <class 'numpy.ndarray'> (64, 2) [-0.09109242 -0.00260091]
# > <class 'numpy.ndarray'> (64, 2) [-0.05197241 -0.05663413]
# > <class 'numpy.ndarray'> (64, 2) [-0.2379251  -0.08175261]
# > <class 'numpy.ndarray'> (64, 2) [-0.0370279  -0.09964252]
# > <class 'numpy.ndarray'> (64, 2) [-0.0481878  -0.10292986]
# > <class 'numpy.ndarray'> (64, 2) [-0.71104866 -0.02038714]
# > <class 'numpy.ndarray'> (64, 2) [-0.0476454  -0.07691102]
# > <class 'numpy.ndarray'> (64, 2) [-0.25182605 -0.23117758]
# > <class 'numpy.ndarray'> (64, 2) [ 0.01065582 -0.27389932]
# > <class 'numpy.ndarray'> (64, 2) [-0.36454946 -0.00289887]
# > <class 'numpy.ndarray'> (64, 2) [-0.41345415 -0.11510822]
# > <class 'numpy.ndarray'> (64, 2) [-0.05244388 -0.04607764]
# > <class 'numpy.ndarray'> (64, 2) [-0.08163265 -0.01115609]
# > <class 'numpy.ndarray'> (64, 2) [-0.12565243  0.01674031]
# > <class 'numpy.ndarray'> (64, 2) [-0.15296555 -0.15072685]
# > <class 'numpy.ndarray'> (64, 2) [ 0.0006721  -0.10204479]
# > <class 'numpy.ndarray'> (64, 2) [-0.31667697 -0.22045681]
# > <class 'numpy.ndarray'> (64, 2) [-0.49810123 -0.18839854]
# > <class 'numpy.ndarray'> (64, 2) [-0.1571382  -0.03608998]
# > <class 'numpy.ndarray'> (64, 2) [-0.10509427 -0.11983375]
# > <class 'numpy.ndarray'> (64, 2) [-0.06812648 -0.10851748]
# > <class 'numpy.ndarray'> (64, 2) [-0.14913088 -0.15704314]
# > <class 'numpy.ndarray'> (64, 2) [-0.03535861 -0.08297149]
# > <class 'numpy.ndarray'> (64, 2) [-0.24483874 -0.22731964]
# > <class 'numpy.ndarray'> (64, 2) [-0.00609851 -0.0535203 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.05262055 -0.10579325]
# > <class 'numpy.ndarray'> (64, 2) [-0.54422623 -0.00382726]
# > <class 'numpy.ndarray'> (64, 2) [-0.12629208  0.00677864]
# > <class 'numpy.ndarray'> (64, 2) [-0.25524014 -0.24947351]
# > <class 'numpy.ndarray'> (64, 2) [-0.47153759 -0.15198182]
# > <class 'numpy.ndarray'> (64, 2) [-0.2234751  -0.01504263]
# > <class 'numpy.ndarray'> (64, 2) [-0.24394913 -0.08663494]
# > <class 'numpy.ndarray'> (64, 2) [-0.08820908 -0.12091024]
# > <class 'numpy.ndarray'> (64, 2) [-0.20720418 -0.05298647]
# > <class 'numpy.ndarray'> (64, 2) [-0.12620391 -0.13544793]
# > <class 'numpy.ndarray'> (64, 2) [-0.12629208  0.00677864]
# > <class 'numpy.ndarray'> (64, 2) [-0.39298671 -0.39332709]
# > <class 'numpy.ndarray'> (64, 2) [-0.57136291 -0.02990583]
# > <class 'numpy.ndarray'> (64, 2) [-0.12383145 -0.13647608]
# > <class 'numpy.ndarray'> (64, 2) [-0.31213981  0.00692637]
# > <class 'numpy.ndarray'> (64, 2) [-0.15424348 -0.16261902]
# > <class 'numpy.ndarray'> (64, 2) [-0.10808129 -0.00444948]
# > <class 'numpy.ndarray'> (64, 2) [ 0.0329474  -0.20584732]
# > <class 'numpy.ndarray'> (64, 2) [-0.25398782 -0.06826548]
# > <class 'numpy.ndarray'> (64, 2) [-0.14341384 -0.10589848]
# > <class 'numpy.ndarray'> (64, 2) [-0.22972402 -0.21458213]
# episode: 27   score: 71.0   memory length: 728   epsilon: 0.5329569060230741
# > <class 'numpy.ndarray'> (64, 2) [-0.47153759 -0.15198182]
# > <class 'numpy.ndarray'> (64, 2) [-0.00801383 -0.04192263]
# > <class 'numpy.ndarray'> (64, 2) [-0.54551935 -0.52127278]
# > <class 'numpy.ndarray'> (64, 2) [-0.20785758 -0.02258696]
# > <class 'numpy.ndarray'> (64, 2) [-0.73903519 -0.03865942]
# > <class 'numpy.ndarray'> (64, 2) [-0.48984489 -0.00965028]
# > <class 'numpy.ndarray'> (64, 2) [-0.28467312 -0.26621732]
# > <class 'numpy.ndarray'> (64, 2) [-0.00499326 -0.01954094]
# > <class 'numpy.ndarray'> (64, 2) [-0.20693985 -0.21544504]
# > <class 'numpy.ndarray'> (64, 2) [-0.16240935 -0.3679933 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.13516322 -0.13333145]
# > <class 'numpy.ndarray'> (64, 2) [-0.11932804 -0.11926   ]
# > <class 'numpy.ndarray'> (64, 2) [-0.11580379 -0.12518728]
# > <class 'numpy.ndarray'> (64, 2) [-0.16939592 -0.0404841 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.71105206 -0.5826332 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.15942174 -0.12049141]
# > <class 'numpy.ndarray'> (64, 2) [-0.20125729 -0.01174963]
# > <class 'numpy.ndarray'> (64, 2) [-0.19498375 -0.02105273]
# > <class 'numpy.ndarray'> (64, 2) [-0.01003074 -0.02175818]
# > <class 'numpy.ndarray'> (64, 2) [-0.47477186 -0.48205465]
# > <class 'numpy.ndarray'> (64, 2) [-0.014232   -0.00307005]
# > <class 'numpy.ndarray'> (64, 2) [-1.029984   -0.06281167]
# > <class 'numpy.ndarray'> (64, 2) [ 0.01699677 -0.21825692]
# > <class 'numpy.ndarray'> (64, 2) [-0.23916194 -0.03246547]
# > <class 'numpy.ndarray'> (64, 2) [-0.2228411  -0.00501497]
# > <class 'numpy.ndarray'> (64, 2) [-0.15273695 -0.13367365]
# > <class 'numpy.ndarray'> (64, 2) [-0.04789805 -0.0153641 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.01844121 -0.08986174]
# > <class 'numpy.ndarray'> (64, 2) [-0.61453193 -0.55546606]
# > <class 'numpy.ndarray'> (64, 2) [-0.01627272 -0.33150426]
# > <class 'numpy.ndarray'> (64, 2) [-0.03535861 -0.08297149]
# > <class 'numpy.ndarray'> (64, 2) [-0.38831949 -0.05692491]
# > <class 'numpy.ndarray'> (64, 2) [-0.12070568 -0.12877277]
# > <class 'numpy.ndarray'> (64, 2) [-0.13326879  0.0364579 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.05129258 -0.02181278]
# > <class 'numpy.ndarray'> (64, 2) [-0.02478015 -0.00227463]
# > <class 'numpy.ndarray'> (64, 2) [-0.22092083  0.00101952]
# > <class 'numpy.ndarray'> (64, 2) [-0.05944589 -0.28941172]
# > <class 'numpy.ndarray'> (64, 2) [-0.68474382 -0.66026318]
# > <class 'numpy.ndarray'> (64, 2) [-0.31879315 -0.11963806]
# > <class 'numpy.ndarray'> (64, 2) [-0.92931378 -0.11235711]
# > <class 'numpy.ndarray'> (64, 2) [-0.36087984 -0.26789385]
# > <class 'numpy.ndarray'> (64, 2) [-0.56180513 -0.55809939]
# > <class 'numpy.ndarray'> (64, 2) [-0.15885454 -0.10970391]
# > <class 'numpy.ndarray'> (64, 2) [-0.05219897 -0.0770181 ]
# > <class 'numpy.ndarray'> (64, 2) [ 0.0067348  -0.28231916]
# > <class 'numpy.ndarray'> (64, 2) [-0.00801383 -0.04192263]
# > <class 'numpy.ndarray'> (64, 2) [-0.09381217 -0.031298  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.849518   -0.87889135]
# > <class 'numpy.ndarray'> (64, 2) [-0.50792313 -0.00526756]
# > <class 'numpy.ndarray'> (64, 2) [-0.19093458  0.01658448]
# > <class 'numpy.ndarray'> (64, 2) [-0.01003074 -0.02175818]
# > <class 'numpy.ndarray'> (64, 2) [-0.20388871 -0.20163764]
# > <class 'numpy.ndarray'> (64, 2) [-0.44758248 -0.06575736]
# > <class 'numpy.ndarray'> (64, 2) [-0.39587864 -0.13132669]
# > <class 'numpy.ndarray'> (64, 2) [-0.00018399 -0.05489073]
# > <class 'numpy.ndarray'> (64, 2) [-0.34445709 -0.08343967]
# > <class 'numpy.ndarray'> (64, 2) [-0.34894893 -0.05604704]
# episode: 28   score: 57.0   memory length: 786   epsilon: 0.5029101620180685
# > <class 'numpy.ndarray'> (64, 2) [-0.16644898 -0.11889029]
# > <class 'numpy.ndarray'> (64, 2) [-0.4468163  -0.01259604]
# > <class 'numpy.ndarray'> (64, 2) [-0.03119793 -0.02242111]
# > <class 'numpy.ndarray'> (64, 2) [-1.22031128 -1.0890466 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.36849841 -0.08629542]
# > <class 'numpy.ndarray'> (64, 2) [-0.0093473  -0.05095959]
# > <class 'numpy.ndarray'> (64, 2) [-0.10427087 -0.12673733]
# > <class 'numpy.ndarray'> (64, 2) [-0.12524039 -0.01304247]
# > <class 'numpy.ndarray'> (64, 2) [-0.26715636 -0.2407338 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.07494394 -0.12823577]
# > <class 'numpy.ndarray'> (64, 2) [-0.42757198 -0.01443285]
# > <class 'numpy.ndarray'> (64, 2) [-0.10515155 -0.19742052]
# > <class 'numpy.ndarray'> (64, 2) [-0.32294813 -0.0439465 ]
# episode: 29   score: 12.0   memory length: 799   epsilon: 0.4964114134310989
# > <class 'numpy.ndarray'> (64, 2) [-0.41260269 -0.01493207]
# > <class 'numpy.ndarray'> (64, 2) [-0.14352252 -0.00130854]
# > <class 'numpy.ndarray'> (64, 2) [-0.12629208  0.00677864]
# > <class 'numpy.ndarray'> (64, 2) [-0.41529483 -0.42496559]
# > <class 'numpy.ndarray'> (64, 2) [ 0.00313212 -0.25739598]
# > <class 'numpy.ndarray'> (64, 2) [-0.24726301 -0.2606377 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.39278501 -0.32363129]
# > <class 'numpy.ndarray'> (64, 2) [-0.14423108 -0.00753479]
# > <class 'numpy.ndarray'> (64, 2) [-0.18776885 -0.08917111]
# > <class 'numpy.ndarray'> (64, 2) [-0.07596254 -0.03009541]
# > <class 'numpy.ndarray'> (64, 2) [-0.08163265 -0.01115609]
# > <class 'numpy.ndarray'> (64, 2) [-0.33977044  0.00044233]
# > <class 'numpy.ndarray'> (64, 2) [-0.41260269 -0.01493207]
# > <class 'numpy.ndarray'> (64, 2) [-0.45415598 -0.14167497]
# > <class 'numpy.ndarray'> (64, 2) [-0.34894893 -0.05604704]
# > <class 'numpy.ndarray'> (64, 2) [-0.40240249 -0.00120944]
# > <class 'numpy.ndarray'> (64, 2) [-0.31879315 -0.11963806]
# > <class 'numpy.ndarray'> (64, 2) [-0.10808129 -0.00444948]
# > <class 'numpy.ndarray'> (64, 2) [-0.01908879 -0.04901754]
# > <class 'numpy.ndarray'> (64, 2) [-0.24483874 -0.22731964]
# episode: 30   score: 19.0   memory length: 819   epsilon: 0.4865769398194536
# > <class 'numpy.ndarray'> (64, 2) [-0.30276614 -0.04348513]
# > <class 'numpy.ndarray'> (64, 2) [-0.55723846  0.05184141]
# > <class 'numpy.ndarray'> (64, 2) [-0.22238779 -0.10261515]
# > <class 'numpy.ndarray'> (64, 2) [-0.25601408 -0.02274689]
# > <class 'numpy.ndarray'> (64, 2) [-0.55346656 -0.4558014 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.0235879  -0.01026877]
# > <class 'numpy.ndarray'> (64, 2) [-0.50279945 -0.04339236]
# > <class 'numpy.ndarray'> (64, 2) [-0.38557124 -0.01956743]
# > <class 'numpy.ndarray'> (64, 2) [-0.00574737 -0.19757673]
# > <class 'numpy.ndarray'> (64, 2) [ 0.02116258 -0.24611472]
# > <class 'numpy.ndarray'> (64, 2) [-0.21941659 -0.07556756]
# > <class 'numpy.ndarray'> (64, 2) [-0.45957375 -0.46185121]
# > <class 'numpy.ndarray'> (64, 2) [-0.67017263 -0.64003396]
# > <class 'numpy.ndarray'> (64, 2) [-0.34691072 -0.31406215]
# > <class 'numpy.ndarray'> (64, 2) [-0.68477726 -0.65420401]
# ...
# > <class 'numpy.ndarray'> (64, 2) [-0.10414823 -0.02993218]
# > <class 'numpy.ndarray'> (64, 2) [-0.15668416 -0.00457434]
# > <class 'numpy.ndarray'> (64, 2) [-0.0658542  -0.06975934]
# > <class 'numpy.ndarray'> (64, 2) [-0.00147977 -0.08448236]
# > <class 'numpy.ndarray'> (64, 2) [-0.32269382  0.0754998 ]
# episode: 91   score: 12.0   memory length: 2000   epsilon: 0.12294130915148117
# > <class 'numpy.ndarray'> (64, 2) [-0.29773027 -0.05755524]
# > <class 'numpy.ndarray'> (64, 2) [-0.13537192 -0.13429059]
# > <class 'numpy.ndarray'> (64, 2) [-0.37311488 -0.08821551]
# > <class 'numpy.ndarray'> (64, 2) [-0.00758039 -0.11103573]
# > <class 'numpy.ndarray'> (64, 2) [-0.66295689 -0.62177205]
# > <class 'numpy.ndarray'> (64, 2) [-0.28891316  0.00654178]
# > <class 'numpy.ndarray'> (64, 2) [-0.61305332 -0.00960118]
# > <class 'numpy.ndarray'> (64, 2) [-0.11807741 -0.10735098]
# > <class 'numpy.ndarray'> (64, 2) [-0.20840563 -0.27572784]
# > <class 'numpy.ndarray'> (64, 2) [-0.2535806  -0.00631738]
# > <class 'numpy.ndarray'> (64, 2) [-0.07427062 -0.04337711]
# > <class 'numpy.ndarray'> (64, 2) [-0.23109409 -0.36093771]
# > <class 'numpy.ndarray'> (64, 2) [-0.63045698 -0.40823734]
# > <class 'numpy.ndarray'> (64, 2) [-0.30276614 -0.04348513]
# > <class 'numpy.ndarray'> (64, 2) [-0.67423987 -0.03911448]
# > <class 'numpy.ndarray'> (64, 2) [-0.25700572 -0.24082583]
# > <class 'numpy.ndarray'> (64, 2) [ -5.28638288e-02   3.97879630e-05]
# > <class 'numpy.ndarray'> (64, 2) [-0.87070316  0.10604343]
# > <class 'numpy.ndarray'> (64, 2) [-0.68800259 -0.1151472 ]
# episode: 92   score: 18.0   memory length: 2000   epsilon: 0.12062632858643366
# > <class 'numpy.ndarray'> (64, 2) [-0.36438048 -0.03193402]
# > <class 'numpy.ndarray'> (64, 2) [-0.1703418  -0.00734086]
# > <class 'numpy.ndarray'> (64, 2) [-0.44183567  0.02077617]
# > <class 'numpy.ndarray'> (64, 2) [-0.0151625  -0.15679987]
# > <class 'numpy.ndarray'> (64, 2) [-0.07658473 -0.0952956 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.26288196 -0.22228965]
# > <class 'numpy.ndarray'> (64, 2) [-0.25433737  0.06850884]
# > <class 'numpy.ndarray'> (64, 2) [-0.30313921 -0.17622226]
# > <class 'numpy.ndarray'> (64, 2) [-0.40430462 -0.0067125 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.54325682 -0.53900093]
# > <class 'numpy.ndarray'> (64, 2) [-0.12349127 -0.11724406]
# > <class 'numpy.ndarray'> (64, 2) [-0.27651113 -0.04581176]
# > <class 'numpy.ndarray'> (64, 2) [-0.26915532 -0.16423824]
# > <class 'numpy.ndarray'> (64, 2) [-0.00238405 -0.01961551]
# > <class 'numpy.ndarray'> (64, 2) [-0.12531114 -0.11861323]
# > <class 'numpy.ndarray'> (64, 2) [-0.10264238 -0.12442006]
# > <class 'numpy.ndarray'> (64, 2) [-0.15565372  0.0088765 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.14884859  0.0707511 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.65775156 -0.6092065 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.03425629 -0.01159928]
# > <class 'numpy.ndarray'> (64, 2) [-0.17402723 -0.01905434]
# > <class 'numpy.ndarray'> (64, 2) [-0.12207162 -0.12341712]
# > <class 'numpy.ndarray'> (64, 2) [-0.43224666 -0.01113459]
# > <class 'numpy.ndarray'> (64, 2) [-0.67423987 -0.03911448]
# > <class 'numpy.ndarray'> (64, 2) [-0.27664411  0.0480473 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.29613504 -0.29962942]
# > <class 'numpy.ndarray'> (64, 2) [-0.53208697  0.0263907 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.54036295 -0.4920952 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.27685735 -0.27860707]
# > <class 'numpy.ndarray'> (64, 2) [-0.45416394  0.04955336]
# > <class 'numpy.ndarray'> (64, 2) [-0.18606383 -0.14269571]
# > <class 'numpy.ndarray'> (64, 2) [-0.43589684 -0.26119232]
# > <class 'numpy.ndarray'> (64, 2) [-0.27651113 -0.04581176]
# > <class 'numpy.ndarray'> (64, 2) [-0.55365866 -0.56700563]
# > <class 'numpy.ndarray'> (64, 2) [-0.66428483 -0.61669469]
# > <class 'numpy.ndarray'> (64, 2) [-0.31128094 -0.29823837]
# > <class 'numpy.ndarray'> (64, 2) [-0.47153759 -0.15198182]
# > <class 'numpy.ndarray'> (64, 2) [-0.10346702 -0.01556304]
# > <class 'numpy.ndarray'> (64, 2) [-0.26517212 -0.04611635]
# > <class 'numpy.ndarray'> (64, 2) [-0.89669859 -0.2224896 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.62834263 -0.63457727]
# > <class 'numpy.ndarray'> (64, 2) [-0.5424431  -0.51802599]
# > <class 'numpy.ndarray'> (64, 2) [-0.76249498 -0.75119436]
# > <class 'numpy.ndarray'> (64, 2) [-0.07592612 -0.01050142]
# > <class 'numpy.ndarray'> (64, 2) [-0.06294174 -0.13886037]
# > <class 'numpy.ndarray'> (64, 2) [-0.02946918 -0.0084115 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.06806591 -0.09837196]
# > <class 'numpy.ndarray'> (64, 2) [-0.2024855  -0.05380009]
# > <class 'numpy.ndarray'> (64, 2) [-0.32395625  0.03144726]
# episode: 93   score: 48.0   memory length: 2000   epsilon: 0.11485529795811826
# > <class 'numpy.ndarray'> (64, 2) [-0.50279945 -0.04339236]
# > <class 'numpy.ndarray'> (64, 2) [-0.01595274 -0.06423647]
# > <class 'numpy.ndarray'> (64, 2) [-0.3962422   0.05717802]
# > <class 'numpy.ndarray'> (64, 2) [-0.733136   -0.13307965]
# > <class 'numpy.ndarray'> (64, 2) [-0.15017876 -0.01804912]
# > <class 'numpy.ndarray'> (64, 2) [-0.1422476  -0.03024583]
# > <class 'numpy.ndarray'> (64, 2) [-0.10133602  0.00468636]
# > <class 'numpy.ndarray'> (64, 2) [-0.04732723 -0.02899633]
# > <class 'numpy.ndarray'> (64, 2) [-0.16843508 -0.1264094 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.85049385 -0.87870783]
# > <class 'numpy.ndarray'> (64, 2) [-0.01165056 -0.04360518]
# > <class 'numpy.ndarray'> (64, 2) [-0.31667697 -0.22045681]
# > <class 'numpy.ndarray'> (64, 2) [-0.32543111 -0.023792  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.05196225 -0.02683003]
# > <class 'numpy.ndarray'> (64, 2) [-0.18455642  0.00090174]
# > <class 'numpy.ndarray'> (64, 2) [-0.1738787  -0.01338473]
# > <class 'numpy.ndarray'> (64, 2) [-0.31502056 -0.03913589]
# > <class 'numpy.ndarray'> (64, 2) [-0.48340929 -0.54321122]
# > <class 'numpy.ndarray'> (64, 2) [-0.28658727 -0.29823744]
# > <class 'numpy.ndarray'> (64, 2) [-0.37393507  0.04953112]
# > <class 'numpy.ndarray'> (64, 2) [-0.00828866 -0.03202426]
# > <class 'numpy.ndarray'> (64, 2) [-0.41529483 -0.42496559]
# > <class 'numpy.ndarray'> (64, 2) [-0.04531849 -0.06085379]
# > <class 'numpy.ndarray'> (64, 2) [-0.14737213  0.03078786]
# > <class 'numpy.ndarray'> (64, 2) [ 0.02116258 -0.24611472]
# > <class 'numpy.ndarray'> (64, 2) [-0.35973671 -0.00449191]
# > <class 'numpy.ndarray'> (64, 2) [-0.1164563  -0.10614298]
# > <class 'numpy.ndarray'> (64, 2) [-0.55681157 -0.06265232]
# > <class 'numpy.ndarray'> (64, 2) [-0.0708317  -0.00983976]
# > <class 'numpy.ndarray'> (64, 2) [-0.14972924 -0.14002517]
# episode: 94   score: 29.0   memory length: 2000   epsilon: 0.11145913789278664
# > <class 'numpy.ndarray'> (64, 2) [-0.43335634 -0.05829684]
# > <class 'numpy.ndarray'> (64, 2) [-0.56831992 -0.56843662]
# > <class 'numpy.ndarray'> (64, 2) [-0.36025721 -0.07638121]
# > <class 'numpy.ndarray'> (64, 2) [-0.88850224 -0.10800123]
# > <class 'numpy.ndarray'> (64, 2) [-0.69998169  0.08573806]
# > <class 'numpy.ndarray'> (64, 2) [-0.20596626 -0.00117405]
# > <class 'numpy.ndarray'> (64, 2) [-0.00551917 -0.00687533]
# > <class 'numpy.ndarray'> (64, 2) [-0.08256869 -0.03226428]
# > <class 'numpy.ndarray'> (64, 2) [-0.01265605 -0.02400127]
# > <class 'numpy.ndarray'> (64, 2) [-0.54619443 -0.51431751]
# > <class 'numpy.ndarray'> (64, 2) [-0.40050143 -0.129491  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.45416394  0.04955336]
# > <class 'numpy.ndarray'> (64, 2) [-0.60529023  0.11792639]
# > <class 'numpy.ndarray'> (64, 2) [ 0.02116258 -0.24611472]
# > <class 'numpy.ndarray'> (64, 2) [-0.37973699 -0.04776345]
# > <class 'numpy.ndarray'> (64, 2) [-0.30440009 -0.29782748]
# > <class 'numpy.ndarray'> (64, 2) [-0.4138996  0.0057341]
# > <class 'numpy.ndarray'> (64, 2) [-0.48733401 -0.04659805]
# > <class 'numpy.ndarray'> (64, 2) [-0.05289286 -0.0241195 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.11807741 -0.10735098]
# > <class 'numpy.ndarray'> (64, 2) [-0.2886664 -0.2945157]
# > <class 'numpy.ndarray'> (64, 2) [-0.10760869 -0.31498268]
# > <class 'numpy.ndarray'> (64, 2) [-0.85279882 -0.8174063 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.44997516 -0.41937339]
# > <class 'numpy.ndarray'> (64, 2) [-0.0648661  -0.03789135]
# > <class 'numpy.ndarray'> (64, 2) [-0.26517212 -0.04611635]
# > <class 'numpy.ndarray'> (64, 2) [-0.18948726  0.02804025]
# > <class 'numpy.ndarray'> (64, 2) [-0.6899966  -0.68298393]
# > <class 'numpy.ndarray'> (64, 2) [-0.71462393 -0.09248686]
# > <class 'numpy.ndarray'> (64, 2) [-0.68164009 -0.05090815]
# > <class 'numpy.ndarray'> (64, 2) [-0.05620653 -0.10777268]
# > <class 'numpy.ndarray'> (64, 2) [-0.15178704 -0.01914519]
# > <class 'numpy.ndarray'> (64, 2) [-0.39109194 -0.29499334]
# > <class 'numpy.ndarray'> (64, 2) [-0.27312058 -0.27496645]
# > <class 'numpy.ndarray'> (64, 2) [-0.001129   -0.04804106]
# > <class 'numpy.ndarray'> (64, 2) [-0.51095796 -0.47408071]
# > <class 'numpy.ndarray'> (64, 2) [-0.13855127 -0.01187568]
# > <class 'numpy.ndarray'> (64, 2) [-0.1626502  -0.13906887]
# episode: 95   score: 37.0   memory length: 2000   epsilon: 0.10730111432922863
# > <class 'numpy.ndarray'> (64, 2) [-0.19733785 -0.17719923]
# > <class 'numpy.ndarray'> (64, 2) [-0.66551715 -0.64100552]
# > <class 'numpy.ndarray'> (64, 2) [-0.25587112 -0.23989625]
# > <class 'numpy.ndarray'> (64, 2) [-0.14404011  0.02702537]
# > <class 'numpy.ndarray'> (64, 2) [-0.66428483 -0.61669469]
# > <class 'numpy.ndarray'> (64, 2) [-0.32130638 -0.33630276]
# > <class 'numpy.ndarray'> (64, 2) [-0.37373421 -0.19637395]
# > <class 'numpy.ndarray'> (64, 2) [-0.13981877 -0.18517613]
# > <class 'numpy.ndarray'> (64, 2) [-0.54531258 -0.56856483]
# > <class 'numpy.ndarray'> (64, 2) [-0.30313921 -0.17622226]
# > <class 'numpy.ndarray'> (64, 2) [-0.12565243  0.01674031]
# > <class 'numpy.ndarray'> (64, 2) [-0.27357507 -0.39359164]
# > <class 'numpy.ndarray'> (64, 2) [-0.32736292  0.00294429]
# > <class 'numpy.ndarray'> (64, 2) [-0.14856611 -0.1357113 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.39741698 -0.28719854]
# > <class 'numpy.ndarray'> (64, 2) [-0.27784473 -0.1197059 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.15327121 -0.04845102]
# > <class 'numpy.ndarray'> (64, 2) [-0.22416446 -0.0090571 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.1478993 -0.0164454]
# > <class 'numpy.ndarray'> (64, 2) [-0.28538871  0.00766249]
# > <class 'numpy.ndarray'> (64, 2) [-0.04003629 -0.24328667]
# > <class 'numpy.ndarray'> (64, 2) [-0.29593992 -0.25164315]
# > <class 'numpy.ndarray'> (64, 2) [-0.44679195 -0.46633464]
# > <class 'numpy.ndarray'> (64, 2) [-0.03280028 -0.0798005 ]
# episode: 96   score: 23.0   memory length: 2000   epsilon: 0.10475528665106192
# > <class 'numpy.ndarray'> (64, 2) [ 0.00108842 -0.03244177]
# > <class 'numpy.ndarray'> (64, 2) [-0.19208491 -0.14108853]
# > <class 'numpy.ndarray'> (64, 2) [-0.12678005 -0.04109706]
# > <class 'numpy.ndarray'> (64, 2) [-0.04506224 -0.06983585]
# > <class 'numpy.ndarray'> (64, 2) [-0.23109409 -0.36093771]
# > <class 'numpy.ndarray'> (64, 2) [-0.01781317 -0.0285405 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.11544728 -0.27756017]
# > <class 'numpy.ndarray'> (64, 2) [-0.56660402 -0.15070194]
# > <class 'numpy.ndarray'> (64, 2) [-0.45417839 -0.470209  ]
# > <class 'numpy.ndarray'> (64, 2) [-1.10833323 -1.12770903]
# > <class 'numpy.ndarray'> (64, 2) [-0.47021228 -0.11819154]
# > <class 'numpy.ndarray'> (64, 2) [-0.37373421 -0.19637395]
# > <class 'numpy.ndarray'> (64, 2) [-0.72354513  0.10416922]
# > <class 'numpy.ndarray'> (64, 2) [-0.04085107 -0.03416646]
# > <class 'numpy.ndarray'> (64, 2) [-0.01554493 -0.18637489]
# > <class 'numpy.ndarray'> (64, 2) [-0.88032961  0.00240523]
# > <class 'numpy.ndarray'> (64, 2) [-0.37905657 -0.1338422 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.61554337 -0.648395  ]
# > <class 'numpy.ndarray'> (64, 2) [-0.2237573   0.02022529]
# > <class 'numpy.ndarray'> (64, 2) [-0.56180513 -0.55809939]
# > <class 'numpy.ndarray'> (64, 2) [-0.21163148 -0.22241119]
# > <class 'numpy.ndarray'> (64, 2) [-0.15961297 -0.24563123]
# > <class 'numpy.ndarray'> (64, 2) [-0.53084803 -0.00301349]
# > <class 'numpy.ndarray'> (64, 2) [-0.16994739 -0.02583956]
# > <class 'numpy.ndarray'> (64, 2) [-0.70681435 -0.72688824]
# > <class 'numpy.ndarray'> (64, 2) [-0.14618245 -0.16217704]
# > <class 'numpy.ndarray'> (64, 2) [-0.09348547 -0.00059154]
# > <class 'numpy.ndarray'> (64, 2) [-1.00021398 -0.97375286]
# > <class 'numpy.ndarray'> (64, 2) [-0.31206349 -0.30362499]
# > <class 'numpy.ndarray'> (64, 2) [-0.0392509  -0.17923762]
# > <class 'numpy.ndarray'> (64, 2) [-0.27681994 -0.25255921]
# > <class 'numpy.ndarray'> (64, 2) [-0.22548707 -0.21625225]
# > <class 'numpy.ndarray'> (64, 2) [-0.41990197 -0.00495914]
# episode: 97   score: 32.0   memory length: 2000   epsilon: 0.10135310569992435
# > <class 'numpy.ndarray'> (64, 2) [-0.69827592 -0.7285462 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.25433737  0.06850884]
# > <class 'numpy.ndarray'> (64, 2) [-0.17738828 -0.16282327]
# > <class 'numpy.ndarray'> (64, 2) [-0.17117804 -0.03624244]
# > <class 'numpy.ndarray'> (64, 2) [-0.45416394  0.04955336]
# > <class 'numpy.ndarray'> (64, 2) [-0.3649396   0.02846817]
# > <class 'numpy.ndarray'> (64, 2) [-0.15951896  0.01039822]
# > <class 'numpy.ndarray'> (64, 2) [-0.18013512  0.06316863]
# > <class 'numpy.ndarray'> (64, 2) [-0.14139792  0.02631789]
# > <class 'numpy.ndarray'> (64, 2) [-0.1833844  -0.00047413]
# > <class 'numpy.ndarray'> (64, 2) [-0.2024855  -0.05380009]
# > <class 'numpy.ndarray'> (64, 2) [-0.39858067  0.02074804]
# > <class 'numpy.ndarray'> (64, 2) [-0.84027648 -0.87654889]
# > <class 'numpy.ndarray'> (64, 2) [-0.66996533 -0.66421396]
# > <class 'numpy.ndarray'> (64, 2) [-0.79206872 -0.04011229]
# > <class 'numpy.ndarray'> (64, 2) [-0.00107201 -0.04457637]
# episode: 98   score: 15.0   memory length: 2000   epsilon: 0.09974356180769112
# > <class 'numpy.ndarray'> (64, 2) [-0.80164564 -0.75399774]
# > <class 'numpy.ndarray'> (64, 2) [-0.01417869  0.00235639]
# > <class 'numpy.ndarray'> (64, 2) [-0.15566836 -0.16755591]
# > <class 'numpy.ndarray'> (64, 2) [-0.19174661 -0.15049939]
# > <class 'numpy.ndarray'> (64, 2) [-0.03595595 -0.13637789]
# > <class 'numpy.ndarray'> (64, 2) [-0.55344498 -0.06521487]
# > <class 'numpy.ndarray'> (64, 2) [-0.00935244 -0.0393817 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.19773762 -0.00512096]
# > <class 'numpy.ndarray'> (64, 2) [-0.11616556 -0.11351745]
# > <class 'numpy.ndarray'> (64, 2) [-0.4232741  -0.07507834]
# > <class 'numpy.ndarray'> (64, 2) [-0.33333558  0.01811996]
# > <class 'numpy.ndarray'> (64, 2) [-0.42589206 -0.37436759]
# > <class 'numpy.ndarray'> (64, 2) [-0.27651113 -0.04581176]
# > <class 'numpy.ndarray'> (64, 2) [-0.07233669 -0.21907353]
# > <class 'numpy.ndarray'> (64, 2) [-0.3079024   0.09622695]
# > <class 'numpy.ndarray'> (64, 2) [-0.13981877 -0.18517613]
# > <class 'numpy.ndarray'> (64, 2) [-0.28754342 -0.24335642]
# > <class 'numpy.ndarray'> (64, 2) [-0.81817216 -0.02756298]
# > <class 'numpy.ndarray'> (64, 2) [-0.19889601 -0.17463511]
# > <class 'numpy.ndarray'> (64, 2) [-0.26461288 -0.15181892]
# > <class 'numpy.ndarray'> (64, 2) [ -1.60938919e-01   1.01055950e-04]
# > <class 'numpy.ndarray'> (64, 2) [-0.22889864 -0.23532426]
# > <class 'numpy.ndarray'> (64, 2) [-0.50410712 -0.49736255]
# > <class 'numpy.ndarray'> (64, 2) [-0.29084563 -0.32796898]
# > <class 'numpy.ndarray'> (64, 2) [-0.29705301 -0.26380581]
# > <class 'numpy.ndarray'> (64, 2) [-0.16844627 -0.15460534]
# > <class 'numpy.ndarray'> (64, 2) [-0.15430579 -0.12133685]
# > <class 'numpy.ndarray'> (64, 2) [-0.85429108 -0.88514626]
# > <class 'numpy.ndarray'> (64, 2) [-0.26706162 -0.14478445]
# > <class 'numpy.ndarray'> (64, 2) [-0.37460086  0.04901165]
# > <class 'numpy.ndarray'> (64, 2) [-0.29414523 -0.0144209 ]
# > <class 'numpy.ndarray'> (64, 2) [-0.0502983  -0.01828469]
# > <class 'numpy.ndarray'> (64, 2) [-0.72920471  0.00933951]
# > <class 'numpy.ndarray'> (64, 2) [-0.05801389 -0.01214762]
# > <class 'numpy.ndarray'> (64, 2) [-0.14000329 -0.00088866]
# > <class 'numpy.ndarray'> (64, 2) [-0.3288281   0.01588236]
# > <class 'numpy.ndarray'> (64, 2) [-0.33333558  0.01811996]
# > <class 'numpy.ndarray'> (64, 2) [-0.4059673  -0.37068224]
# > <class 'numpy.ndarray'> (64, 2) [-0.12469496 -0.03312704]
# > <class 'numpy.ndarray'> (64, 2) [-0.12539257 -0.18833588]
# episode: 99   score: 39.0   memory length: 2000   epsilon: 0.09583064289751587
